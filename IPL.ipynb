# %%
import numpy as np
import pandas as pd

# %%
matches=pd.read_csv('ipl-matches.csv')

# %%
matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
list(set(matches['Team1'].unique()))
# Out:
# ['Rising Pune Supergiants',
#  'Delhi Capitals',
#  'Kochi Tuskers Kerala',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Rising Pune Supergiant',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Deccan Chargers',
#  'Gujarat Titans',
#  'Pune Warriors',
#  'Gujarat Lions',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore',
#  'Punjab Kings']

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
temp_df=matches[(matches['Team1']=='Rajasthan Royals') & (matches['Team2']=='Royal Challengers Bangalore') | (matches['Team2']=='Rajasthan Royals') & (matches['Team1']=='Royal Challengers Bangalore')]

# %%
total_matches=temp_df.shape[0]

# %%
total_matches
# Out:
# 27

# %%
temp_df
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 1    1312199  Ahmedabad  2022-05-27     2022  Qualifier 2
# 35   1304085       Pune  2022-04-26     2022           39
# 61   1304059     Mumbai  2022-04-05     2022           13
# 91   1254103      Dubai  2021-09-29     2021           43
# 118  1254073     Mumbai  2021-04-22     2021           16
# 160  1216522        NaN  2020-10-17  2020/21           33
# 178  1216514  Abu Dhabi  2020-10-03  2020/21           15
# 205  1178424  Bengaluru  2019-04-30     2019           49
# 240  1175369     Jaipur  2019-04-02     2019           14
# 261  1136613     Jaipur  2018-05-19     2018           53
# 303  1136571  Bengaluru  2018-04-15     2018           11
# 435   829819       Pune  2015-05-20     2015   Eliminator
# 464   829763  Bangalore  2015-04-29     2015           29
# 470   829749  Ahmedabad  2015-04-24     2015           22
# 518   733999  Bangalore  2014-05-11     2014           35
# ...

# %%
temp_df['WinningTeam'].value_counts()
# Out:
# Royal Challengers Bangalore    13
# Rajasthan Royals               12
# Name: WinningTeam, dtype: int64

# %%
matches_won_team1=temp_df['WinningTeam'].value_counts()['Rajasthan Royals']
matches_won_team2=temp_df['WinningTeam'].value_counts()['Royal Challengers Bangalore']

# %%
matches_won_team1
# Out:
# 12

# %%
matches_won_team2
# Out:
# 13

# %%
draws=total_matches-(matches_won_team1+matches_won_team2)

# %%
draws
# Out:
# 2

# %%
def team_vs_team(team1,team2):
    
    temp_df=matches[(matches['Team1']==team1) & (matches['Team2']==team2) | (matches['Team2']==team1) & (matches['Team1']==team2)]
    total_matches=temp_df.shape[0]
    
    matches_won_team1=temp_df['WinningTeam'].value_counts()[team1]
    matches_won_team2=temp_df['WinningTeam'].value_counts()[team2]
    
    draws=total_matches-(matches_won_team1+matches_won_team2)
    
    response={
        'total_matches':total_matches,
        team1:matches_won_team1,
        team2:matches_won_team2,
        'draw/no_result':draws
    }
    
    return response

# %%
team_vs_team('Kolkata Knight Riders','Mumbai Indians')
# Out:
# {'total_matches': 31,
#  'Kolkata Knight Riders': 9,
#  'Mumbai Indians': 22,
#  'draw/no_result': 0}

# %%
len(matches['Team1'].unique())
# Out:
# 18

# %%
len(set(matches['Team1']))
# Out:
# 18
